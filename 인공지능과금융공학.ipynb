# %%
# !git clone https://github.com/pfnet-research/pfhedge.git
# Out:
# Cloning into 'pfhedge'...
# remote: Enumerating objects: 6194, done.
# remote: Counting objects: 100% (824/824), done.
# remote: Compressing objects: 100% (256/256), done.
# remote: Total 6194 (delta 663), reused 568 (delta 568), pack-reused 5370 (from 2)
# Receiving objects: 100% (6194/6194), 5.91 MiB | 11.80 MiB/s, done.
# Resolving deltas: 100% (4728/4728), done.

# %%
import os

result = []
for root, _, files in os.walk("pfhedge/pfhedge"):
    for file in files:
        full_path = os.path.join(root, file)
        result.append(full_path)

# len(result)
result
# Out:
# ['pfhedge/pfhedge/version.py',
#  'pfhedge/pfhedge/__init__.py',
#  'pfhedge/pfhedge/autogreek.py',
#  'pfhedge/pfhedge/instruments/__init__.py',
#  'pfhedge/pfhedge/instruments/base.py',
#  'pfhedge/pfhedge/instruments/primary/__init__.py',
#  'pfhedge/pfhedge/instruments/primary/cir.py',
#  'pfhedge/pfhedge/instruments/primary/heston.py',
#  'pfhedge/pfhedge/instruments/primary/merton_jump.py',
#  'pfhedge/pfhedge/instruments/primary/brownian.py',
#  'pfhedge/pfhedge/instruments/primary/rough_bergomi.py',
#  'pfhedge/pfhedge/instruments/primary/local_volatility.py',
#  'pfhedge/pfhedge/instruments/primary/base.py',
#  'pfhedge/pfhedge/instruments/primary/vasicek.py',
#  'pfhedge/pfhedge/instruments/primary/kou_jump.py',
#  'pfhedge/pfhedge/instruments/derivative/lookback.py',
#  'pfhedge/pfhedge/instruments/derivative/__init__.py',
#  'pfhedge/pfhedge/instruments/derivative/american_binary.py',
#  'pfhedge/pfhedge/instruments/derivative/european_binary.py',
#  'pfhedge/pfhedge/instruments/derivative/cliquet.py',
#  'pfhedge/pfhedge/instruments/derivative/european.py',
#  'pfhedge/pfhedge/instruments/derivative/variance_swap.py',
#  'pfhedge/pfhedge/instruments/derivative/base.py',
#  'pfhedge/pfhedge/_utils/hook.py',
#  'pfhedge/pfhedge/_utils/doc.py',
#  'pfhedge/pfhedge/_utils/__init__.py',
#  'pfhedge/pfhedge/_utils/typing.py',
#  'pfhedge/pfhedge/_utils/bisect.py',
#  'pfhedge/pfhedge/_utils/operations.py',
#  'pfhedge/pfhedge/_utils/str.py',
#  'pfhedge/pfhedge/_utils/lazy.py',
#  'pfhedge/pfhedge/_utils/parse.py',
#  'pfhedge/pfhedge/_utils/testing.py',
#  'pfhedge/pfhedge/stochastic/__init__.py',
#  'pfhedge/pfhedge/stochastic/cir.py',
#  'pfhedge/pfhedge/stochastic/_utils.py',
#  'pfhedge/pfhedge/stochastic/heston.py',
#  'pfhedge/pfhedge/stochastic/merton_jump.py',
#  'pfhedge/pfhedge/stochastic/brownian.py',
#  'pfhedge/pfhedge/stochastic/random.py',
#  'pfhedge/pfhedge/stochastic/rough_bergomi.py',
#  'pfhedge/pfhedge/stochastic/local_volatility.py',
#  'pfhedge/pfhedge/stochastic/vasicek.py',
#  'pfhedge/pfhedge/stochastic/kou_jump.py',
#  'pfhedge/pfhedge/stochastic/engine.py',
#  'pfhedge/pfhedge/nn/__init__.py',
#  'pfhedge/pfhedge/nn/functional.py',
#  'pfhedge/pfhedge/nn/modules/hedger.py',
#  'pfhedge/pfhedge/nn/modules/mlp.py',
#  'pfhedge/pfhedge/nn/modules/svi.py',
#  'pfhedge/pfhedge/nn/modules/__init__.py',
#  'pfhedge/pfhedge/nn/modules/loss.py',
#  'pfhedge/pfhedge/nn/modules/clamp.py',
#  'pfhedge/pfhedge/nn/modules/ww.py',
#  'pfhedge/pfhedge/nn/modules/naked.py',
#  'pfhedge/pfhedge/nn/modules/bs/_base.py',
#  'pfhedge/pfhedge/nn/modules/bs/lookback.py',
#  'pfhedge/pfhedge/nn/modules/bs/__init__.py',
#  'pfhedge/pfhedge/nn/modules/bs/american_binary.py',
#  'pfhedge/pfhedge/nn/modules/bs/european_binary.py',
#  'pfhedge/pfhedge/nn/modules/bs/european.py',
#  'pfhedge/pfhedge/nn/modules/bs/black_scholes.py',
#  'pfhedge/pfhedge/features/_base.py',
#  'pfhedge/pfhedge/features/container.py',
#  'pfhedge/pfhedge/features/__init__.py',
#  'pfhedge/pfhedge/features/_getter.py',
#  'pfhedge/pfhedge/features/features.py']

# %%
import ast

def analyze_python_file(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        code = f.read()
    tree = ast.parse(code, filename=file_path)

    print(f"📄 Analyzing: {file_path}")

    for node in tree.body:
        # Top-level imports
        if isinstance(node, ast.Import):
            for alias in node.names:
                #print(f"📦 Import: {alias.name}")
                pass
        elif isinstance(node, ast.ImportFrom):
            for alias in node.names:
                #print(f"📦 From {node.module} import {alias.name}")
                pass

        # Top-level functions
        elif isinstance(node, ast.FunctionDef):
            print(f"🔧 Function: {node.name}()")

        # Classes and their methods
        elif isinstance(node, ast.ClassDef):
            print(f"🏷️  Class: {node.name}")
            for item in node.body:
                if isinstance(item, ast.FunctionDef):
                    print(f"   └── 🧩 Method: {item.name}()")

    print()


for i in result:
    analyze_python_file(i)
# Out:
# 📄 Analyzing: pfhedge/pfhedge/version.py
#
# 📄 Analyzing: pfhedge/pfhedge/__init__.py
#
# 📄 Analyzing: pfhedge/pfhedge/autogreek.py
# 🔧 Function: delta()
# 🔧 Function: gamma()
# 🔧 Function: gamma_from_delta()
# 🔧 Function: vega()
# 🔧 Function: theta()
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/__init__.py
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/base.py
# 🏷️  Class: BaseInstrument
#    └── 🧩 Method: spot()
#    └── 🧩 Method: is_listed()
#    └── 🧩 Method: simulate()
#    └── 🧩 Method: to()
#    └── 🧩 Method: cpu()
#    └── 🧩 Method: cuda()
#    └── 🧩 Method: double()
#    └── 🧩 Method: float()
#    └── 🧩 Method: half()
#    └── 🧩 Method: float64()
#    └── 🧩 Method: float32()
#    └── 🧩 Method: float16()
#    └── 🧩 Method: bfloat16()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: _get_name()
#    └── 🧩 Method: _dinfo()
# 🏷️  Class: Instrument
#    └── 🧩 Method: __init__()
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/primary/__init__.py
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/primary/cir.py
# 🏷️  Class: CIRRate
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: default_init_state()
#    └── 🧩 Method: simulate()
#    └── 🧩 Method: extra_repr()
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/primary/heston.py
# 🏷️  Class: HestonStock
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: default_init_state()
#    └── 🧩 Method: volatility()
#    └── 🧩 Method: simulate()
#    └── 🧩 Method: extra_repr()
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/primary/merton_jump.py
# 🏷️  Class: MertonJumpStock
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: default_init_state()
#    └── 🧩 Method: volatility()
#    └── 🧩 Method: variance()
#    └── 🧩 Method: simulate()
#    └── 🧩 Method: extra_repr()
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/primary/brownian.py
# 🏷️  Class: BrownianStock
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: default_init_state()
#    └── 🧩 Method: volatility()
#    └── 🧩 Method: variance()
#    └── 🧩 Method: simulate()
#    └── 🧩 Method: extra_repr()
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/primary/rough_bergomi.py
# 🏷️  Class: RoughBergomiStock
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: default_init_state()
#    └── 🧩 Method: volatility()
#    └── 🧩 Method: simulate()
#    └── 🧩 Method: extra_repr()
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/primary/local_volatility.py
# 🏷️  Class: LocalVolatilityStock
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: default_init_state()
#    └── 🧩 Method: variance()
#    └── 🧩 Method: simulate()
#    └── 🧩 Method: extra_repr()
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/primary/base.py
# 🏷️  Class: BasePrimary
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: default_init_state()
#    └── 🧩 Method: simulate()
#    └── 🧩 Method: register_buffer()
#    └── 🧩 Method: named_buffers()
#    └── 🧩 Method: buffers()
#    └── 🧩 Method: get_buffer()
#    └── 🧩 Method: __getattr__()
#    └── 🧩 Method: spot()
#    └── 🧩 Method: is_listed()
#    └── 🧩 Method: to()
#    └── 🧩 Method: _parse_to()
#    └── 🧩 Method: __repr__()
# 🏷️  Class: Primary
#    └── 🧩 Method: __init__()
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/primary/vasicek.py
# 🏷️  Class: VasicekRate
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: default_init_state()
#    └── 🧩 Method: simulate()
#    └── 🧩 Method: extra_repr()
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/primary/kou_jump.py
# 🏷️  Class: KouJumpStock
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: default_init_state()
#    └── 🧩 Method: volatility()
#    └── 🧩 Method: variance()
#    └── 🧩 Method: simulate()
#    └── 🧩 Method: extra_repr()
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/derivative/lookback.py
# 🏷️  Class: LookbackOption
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: payoff_fn()
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/derivative/__init__.py
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/derivative/american_binary.py
# 🏷️  Class: AmericanBinaryOption
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: payoff_fn()
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/derivative/european_binary.py
# 🏷️  Class: EuropeanBinaryOption
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: payoff_fn()
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/derivative/cliquet.py
# 🏷️  Class: EuropeanForwardStartOption
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: _start_index()
#    └── 🧩 Method: payoff_fn()
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/derivative/european.py
# 🏷️  Class: EuropeanOption
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: payoff_fn()
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/derivative/variance_swap.py
# 🏷️  Class: VarianceSwap
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: payoff_fn()
#
# 📄 Analyzing: pfhedge/pfhedge/instruments/derivative/base.py
# 🏷️  Class: BaseDerivative
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: dtype()
#    └── 🧩 Method: device()
#    └── 🧩 Method: simulate()
#    └── 🧩 Method: ul()
#    └── 🧩 Method: to()
#    └── 🧩 Method: payoff_fn()
#    └── 🧩 Method: payoff()
#    └── 🧩 Method: list()
#    └── 🧩 Method: delist()
#    └── 🧩 Method: is_listed()
#    └── 🧩 Method: add_clause()
#    └── 🧩 Method: named_clauses()
#    └── 🧩 Method: clauses()
#    └── 🧩 Method: register_underlier()
#    └── 🧩 Method: named_underliers()
#    └── 🧩 Method: underliers()
#    └── 🧩 Method: get_underlier()
#    └── 🧩 Method: __getattr__()
#    └── 🧩 Method: __setattr__()
#    └── 🧩 Method: spot()
#    └── 🧩 Method: __repr__()
# 🏷️  Class: Derivative
#    └── 🧩 Method: __init__()
# 🏷️  Class: OptionMixin
#    └── 🧩 Method: moneyness()
#    └── 🧩 Method: log_moneyness()
#    └── 🧩 Method: time_to_maturity()
#    └── 🧩 Method: max_moneyness()
#    └── 🧩 Method: max_log_moneyness()
# 🏷️  Class: BaseOption
#    └── 🧩 Method: __init__()
#
# 📄 Analyzing: pfhedge/pfhedge/_utils/hook.py
# 🔧 Function: save_prev_output()
#
# 📄 Analyzing: pfhedge/pfhedge/_utils/doc.py
# 🔧 Function: _set_docstring()
# 🔧 Function: _set_attr_and_docstring()
#
# 📄 Analyzing: pfhedge/pfhedge/_utils/__init__.py
#
# 📄 Analyzing: pfhedge/pfhedge/_utils/typing.py
#
# 📄 Analyzing: pfhedge/pfhedge/_utils/bisect.py
# 🔧 Function: bisect()
# 🔧 Function: find_implied_volatility()
#
# 📄 Analyzing: pfhedge/pfhedge/_utils/operations.py
# 🔧 Function: ensemble_mean()
#
# 📄 Analyzing: pfhedge/pfhedge/_utils/str.py
# 🔧 Function: _addindent()
# 🔧 Function: _format_float()
#
# 📄 Analyzing: pfhedge/pfhedge/_utils/lazy.py
# 🔧 Function: has_lazy()
#
# 📄 Analyzing: pfhedge/pfhedge/_utils/parse.py
# 🔧 Function: _as_optional_tensor()
# 🔧 Function: parse_spot()
# 🔧 Function: parse_volatility()
# 🔧 Function: parse_time_to_maturity()
#
# 📄 Analyzing: pfhedge/pfhedge/_utils/testing.py
# 🔧 Function: assert_monotone()
# 🔧 Function: assert_convex()
# 🔧 Function: assert_cash_invariant()
# 🔧 Function: assert_cash_equivalent()
#
# 📄 Analyzing: pfhedge/pfhedge/stochastic/__init__.py
#
# 📄 Analyzing: pfhedge/pfhedge/stochastic/cir.py
# 🔧 Function: _get_epsilon()
# 🔧 Function: generate_cir()
#
# 📄 Analyzing: pfhedge/pfhedge/stochastic/_utils.py
# 🔧 Function: cast_state()
#
# 📄 Analyzing: pfhedge/pfhedge/stochastic/heston.py
# 🏷️  Class: SpotVarianceTuple
#    └── 🧩 Method: __repr__()
#    └── 🧩 Method: volatility()
# 🔧 Function: generate_heston()
#
# 📄 Analyzing: pfhedge/pfhedge/stochastic/merton_jump.py
# 🔧 Function: generate_merton_jump()
#
# 📄 Analyzing: pfhedge/pfhedge/stochastic/brownian.py
# 🔧 Function: generate_brownian()
# 🔧 Function: generate_geometric_brownian()
#
# 📄 Analyzing: pfhedge/pfhedge/stochastic/random.py
# 🔧 Function: randn_antithetic()
# 🔧 Function: randn_sobol_boxmuller()
#
# 📄 Analyzing: pfhedge/pfhedge/stochastic/rough_bergomi.py
# 🔧 Function: generate_rough_bergomi()
#
# 📄 Analyzing: pfhedge/pfhedge/stochastic/local_volatility.py
# 🏷️  Class: LocalVolatilityTuple
#    └── 🧩 Method: __repr__()
#    └── 🧩 Method: variance()
# 🔧 Function: generate_local_volatility_process()
#
# 📄 Analyzing: pfhedge/pfhedge/stochastic/vasicek.py
# 🔧 Function: generate_vasicek()
#
# 📄 Analyzing: pfhedge/pfhedge/stochastic/kou_jump.py
# 🔧 Function: generate_kou_jump()
#
# 📄 Analyzing: pfhedge/pfhedge/stochastic/engine.py
# 🔧 Function: _get_numel()
# 🏷️  Class: RandnSobolBoxMuller
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: __call__()
#    └── 🧩 Method: _generate_1d()
#
# 📄 Analyzing: pfhedge/pfhedge/nn/__init__.py
#
# 📄 Analyzing: pfhedge/pfhedge/nn/functional.py
# 🔧 Function: european_payoff()
# 🔧 Function: lookback_payoff()
# 🔧 Function: american_binary_payoff()
# 🔧 Function: european_binary_payoff()
# 🔧 Function: european_forward_start_payoff()
# 🔧 Function: exp_utility()
# 🔧 Function: isoelastic_utility()
# 🔧 Function: entropic_risk_measure()
# 🔧 Function: topp()
# 🔧 Function: expected_shortfall()
# 🔧 Function: _min_values()
# 🔧 Function: _max_values()
# 🔧 Function: value_at_risk()
# 🔧 Function: quadratic_cvar()
# 🔧 Function: leaky_clamp()
# 🔧 Function: clamp()
# 🔧 Function: realized_variance()
# 🔧 Function: realized_volatility()
# 🔧 Function: pl()
# 🔧 Function: terminal_value()
# 🔧 Function: ncdf()
# 🔧 Function: npdf()
# 🔧 Function: d1()
# 🔧 Function: d2()
# 🔧 Function: ww_width()
# 🔧 Function: svi_variance()
# 🔧 Function: bilerp()
# 🔧 Function: _bs_theta_gamma_relation()
# 🔧 Function: _bs_vega_gamma_relation()
# 🔧 Function: bs_european_price()
# 🔧 Function: bs_european_delta()
# 🔧 Function: bs_european_gamma()
# 🔧 Function: bs_european_vega()
# 🔧 Function: bs_european_theta()
# 🔧 Function: bs_european_binary_price()
# 🔧 Function: bs_european_binary_delta()
# 🔧 Function: bs_european_binary_gamma()
# 🔧 Function: bs_european_binary_vega()
# 🔧 Function: bs_european_binary_theta()
# 🔧 Function: bs_american_binary_price()
# 🔧 Function: bs_american_binary_delta()
# 🔧 Function: bs_american_binary_gamma()
# 🔧 Function: bs_american_binary_vega()
# 🔧 Function: bs_american_binary_theta()
# 🔧 Function: bs_lookback_price()
# 🔧 Function: bs_lookback_delta()
# 🔧 Function: bs_lookback_gamma()
# 🔧 Function: bs_lookback_vega()
# 🔧 Function: bs_lookback_theta()
# 🔧 Function: box_muller()
#
# 📄 Analyzing: pfhedge/pfhedge/nn/modules/hedger.py
# 🏷️  Class: Hedger
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: forward()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: get_input()
#    └── 🧩 Method: _get_hedge()
#    └── 🧩 Method: compute_hedge()
#    └── 🧩 Method: compute_portfolio()
#    └── 🧩 Method: compute_pl()
#    └── 🧩 Method: compute_pnl()
#    └── 🧩 Method: compute_loss()
#    └── 🧩 Method: _configure_optimizer()
#    └── 🧩 Method: fit()
#    └── 🧩 Method: price()
#
# 📄 Analyzing: pfhedge/pfhedge/nn/modules/mlp.py
# 🏷️  Class: MultiLayerPerceptron
#    └── 🧩 Method: __init__()
#
# 📄 Analyzing: pfhedge/pfhedge/nn/modules/svi.py
# 🏷️  Class: SVIVariance
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: forward()
#    └── 🧩 Method: extra_repr()
#
# 📄 Analyzing: pfhedge/pfhedge/nn/modules/__init__.py
#
# 📄 Analyzing: pfhedge/pfhedge/nn/modules/loss.py
# 🏷️  Class: HedgeLoss
#    └── 🧩 Method: forward()
#    └── 🧩 Method: cash()
# 🏷️  Class: EntropicRiskMeasure
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: forward()
#    └── 🧩 Method: cash()
# 🏷️  Class: EntropicLoss
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: forward()
#    └── 🧩 Method: cash()
# 🏷️  Class: IsoelasticLoss
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: forward()
# 🏷️  Class: ExpectedShortfall
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: forward()
#    └── 🧩 Method: cash()
# 🏷️  Class: QuadraticCVaR
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: forward()
#    └── 🧩 Method: cash()
# 🏷️  Class: OCE
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: forward()
#
# 📄 Analyzing: pfhedge/pfhedge/nn/modules/clamp.py
# 🏷️  Class: LeakyClamp
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: forward()
# 🏷️  Class: Clamp
#    └── 🧩 Method: forward()
#
# 📄 Analyzing: pfhedge/pfhedge/nn/modules/ww.py
# 🏷️  Class: WhalleyWilmott
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: inputs()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: forward()
#    └── 🧩 Method: width()
#
# 📄 Analyzing: pfhedge/pfhedge/nn/modules/naked.py
# 🏷️  Class: Naked
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: forward()
#
# 📄 Analyzing: pfhedge/pfhedge/nn/modules/bs/_base.py
# 🏷️  Class: BSModuleMixin
#    └── 🧩 Method: forward()
#    └── 🧩 Method: price()
#    └── 🧩 Method: delta()
#    └── 🧩 Method: gamma()
#    └── 🧩 Method: vega()
#    └── 🧩 Method: theta()
#    └── 🧩 Method: inputs()
# 🔧 Function: acquire_params_from_derivative_0()
# 🔧 Function: acquire_params_from_derivative_1()
# 🔧 Function: acquire_params_from_derivative_2()
#
# 📄 Analyzing: pfhedge/pfhedge/nn/modules/bs/lookback.py
# 🏷️  Class: BSLookbackOption
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: from_derivative()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: inputs()
#    └── 🧩 Method: price()
#    └── 🧩 Method: delta()
#    └── 🧩 Method: gamma()
#    └── 🧩 Method: vega()
#    └── 🧩 Method: theta()
#    └── 🧩 Method: implied_volatility()
#
# 📄 Analyzing: pfhedge/pfhedge/nn/modules/bs/__init__.py
#
# 📄 Analyzing: pfhedge/pfhedge/nn/modules/bs/american_binary.py
# 🏷️  Class: BSAmericanBinaryOption
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: from_derivative()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: price()
#    └── 🧩 Method: delta()
#    └── 🧩 Method: gamma()
#    └── 🧩 Method: vega()
#    └── 🧩 Method: theta()
#    └── 🧩 Method: implied_volatility()
#
# 📄 Analyzing: pfhedge/pfhedge/nn/modules/bs/european_binary.py
# 🏷️  Class: BSEuropeanBinaryOption
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: from_derivative()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: inputs()
#    └── 🧩 Method: price()
#    └── 🧩 Method: delta()
#    └── 🧩 Method: gamma()
#    └── 🧩 Method: vega()
#    └── 🧩 Method: theta()
#    └── 🧩 Method: implied_volatility()
#
# 📄 Analyzing: pfhedge/pfhedge/nn/modules/bs/european.py
# 🏷️  Class: BSEuropeanOption
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: from_derivative()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: delta()
#    └── 🧩 Method: gamma()
#    └── 🧩 Method: vega()
#    └── 🧩 Method: theta()
#    └── 🧩 Method: price()
#    └── 🧩 Method: implied_volatility()
#
# 📄 Analyzing: pfhedge/pfhedge/nn/modules/bs/black_scholes.py
# 🏷️  Class: BlackScholesModuleFactory
#    └── 🧩 Method: __new__()
#    └── 🧩 Method: register_module()
#    └── 🧩 Method: named_modules()
#    └── 🧩 Method: names()
#    └── 🧩 Method: features()
#    └── 🧩 Method: get_class()
#    └── 🧩 Method: get_class_from_derivative()
# 🏷️  Class: BlackScholes
#    └── 🧩 Method: __new__()
#
# 📄 Analyzing: pfhedge/pfhedge/features/_base.py
# 🏷️  Class: Feature
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: get()
#    └── 🧩 Method: of()
#    └── 🧩 Method: register_derivative()
#    └── 🧩 Method: register_hedger()
#    └── 🧩 Method: _get_name()
#    └── 🧩 Method: is_state_dependent()
#    └── 🧩 Method: __str__()
#    └── 🧩 Method: __getitem__()
# 🏷️  Class: StateIndependentFeature
#    └── 🧩 Method: of()
#
# 📄 Analyzing: pfhedge/pfhedge/features/container.py
# 🏷️  Class: FeatureList
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: __len__()
#    └── 🧩 Method: get()
#    └── 🧩 Method: __str__()
#    └── 🧩 Method: __repr__()
#    └── 🧩 Method: of()
#    └── 🧩 Method: is_state_dependent()
# 🏷️  Class: ModuleOutput
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: extra_repr()
#    └── 🧩 Method: forward()
#    └── 🧩 Method: get()
#    └── 🧩 Method: of()
#    └── 🧩 Method: is_state_dependent()
#
# 📄 Analyzing: pfhedge/pfhedge/features/__init__.py
#
# 📄 Analyzing: pfhedge/pfhedge/features/_getter.py
# 🏷️  Class: FeatureFactory
#    └── 🧩 Method: __new__()
#    └── 🧩 Method: register_feature()
#    └── 🧩 Method: named_features()
#    └── 🧩 Method: names()
#    └── 🧩 Method: features()
#    └── 🧩 Method: get_class()
#    └── 🧩 Method: get_instance()
# 🔧 Function: get_feature()
# 🔧 Function: list_feature_dict()
# 🔧 Function: list_feature_names()
# 🔧 Function: list_features()
#
# 📄 Analyzing: pfhedge/pfhedge/features/features.py
# 🏷️  Class: OptionType
# 🏷️  Class: Moneyness
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: __str__()
#    └── 🧩 Method: get()
# 🏷️  Class: LogMoneyness
#    └── 🧩 Method: __init__()
# 🏷️  Class: TimeToMaturity
#    └── 🧩 Method: get()
# 🏷️  Class: ExpiryTime
#    └── 🧩 Method: __str__()
# 🏷️  Class: UnderlierSpot
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: __str__()
#    └── 🧩 Method: get()
# 🏷️  Class: UnderlierLogSpot
#    └── 🧩 Method: __init__()
# 🏷️  Class: Spot
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: __str__()
#    └── 🧩 Method: get()
# 🏷️  Class: Volatility
#    └── 🧩 Method: get()
# 🏷️  Class: Variance
#    └── 🧩 Method: get()
# 🏷️  Class: PrevHedge
#    └── 🧩 Method: get()
# 🏷️  Class: Barrier
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: __repr__()
#    └── 🧩 Method: get()
# 🏷️  Class: Zeros
#    └── 🧩 Method: get()
# 🏷️  Class: Ones
#    └── 🧩 Method: get()
# 🏷️  Class: Empty
#    └── 🧩 Method: get()
# 🏷️  Class: MaxMoneyness
#    └── 🧩 Method: __init__()
#    └── 🧩 Method: __str__()
#    └── 🧩 Method: get()
# 🏷️  Class: MaxLogMoneyness
#    └── 🧩 Method: __init__()
